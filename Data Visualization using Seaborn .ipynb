# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '__warningregistry__', '_orig_rc_params', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'external', 'factorplot', 'get_data_home', 'get_dataset_names', 'heatmap', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'lvplot', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regp
# ...

# %%
flights=sns.load_dataset("flights")

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
rel=sns.relplot(x="month",y="passengers",hue="year",data=flights)
rel.set_xticklabels(rotation=45) 
#Plotted to figure out which month the number of passengers are high - also gives a relationship with the year. -
#it is observed that the No. of passengers are high during May to sept.

# %%
rel=sns.relplot(x="month",y="passengers",kind="line",hue="year",data=flights)
rel.set_xticklabels(rotation=45)

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="time", y="total_bill",hue="sex",data=tips)
#compares total bill during the time of the day - infers higher income during dinner & mostly male.

# %%
sns.lineplot(x="size",y="total_bill",data=tips,hue="sex")

# %%
sns.boxenplot(x=tips["total_bill"])

# %%
sns.boxenplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="sex",y="total_bill",kind="strip",hue="time",data=tips)

# %%
sns.catplot(x="sex",kind="count",hue="time",data=tips)

# %%
catpl=sns.catplot(x="sex",y="total_bill",kind="point",hue="time",data=tips)
plt.title("relationship b/w sex & Total Bill at particular business hours")
# Out:
# Text(0.5, 1.0, 'relationship b/w sex & Total Bill at particular business hours')

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
